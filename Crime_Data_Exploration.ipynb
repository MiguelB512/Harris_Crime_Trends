# %% [markdown]
# # Exploration or Crime data

# %% [markdown]
# ### Import Dependencies

# %%
# Import dependencies
import os 
import pandas as pd
import matplotlib as plt
import regex as re

# %%
# Import CSV file
df = pd.read_csv('Resources/Crime_Index_Greater_Houston_Area_2015_2020.csv')
df.head()
# Out:
#      AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0  BELLVILLE PD       0     3        2        6        17       45
# 1  SEALY ISD PD       0     0        0        1         1        5
# 2  AUSTIN CO SO       0     3        2       13        48       61
# 3     WALLIS PD       0     0        0        0         3       10
# 4      SEALY PD       0     2        0       33        52      162
#
#    Auto Theft  Total  Population  Year         County
# 0           0     73        4235  2015  Austin County
# 1           0      7           0  2015  Austin County
# 2           8    135       17499  2015  Austin County
# 3           0     13        1284  2015  Austin County
# 4           5    254        6336  2015  Austin County

# %% [markdown]
# ### Data Types

# %%
# Data types
df.dtypes

# %%
# Assigning 'Year' column as 'object' datatype tp prevent .sum() adding years together
df = df.astype({"Year":'object'})
df.dtypes
# Out:
# AgencyName    object
# Murder         int64
# Rape           int64
# Robbery        int64
# Assault        int64
# Burglary       int64
# Larceny        int64
# Auto Theft     int64
# Total          int64
# Population     int64
# Year          object
# County        object
# dtype: object

# %% [markdown]
# ### Grouping data by year and making year based DataFrames

# %%
# .groupby Year
year_df = df.groupby('Year')
year_df.head(10)
# Out:
#                 AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0             BELLVILLE PD       0     3        2        6        17       45
# 1             SEALY ISD PD       0     0        0        1         1        5
# 2             AUSTIN CO SO       0     3        2       13        48       61
# 3                WALLIS PD       0     0        0        0         3       10
# 4                 SEALY PD       0     2        0       33        52      162
# 5          DANBURY PD (NR)       0     1        0        0         0        2
# 6    ALVIN COMM COLLEGE PD       0     0        0        0         0       13
# 7        SURFSIDE BEACH PD       0     0        0        2         4       11
# 8          ANGLETON ISD PD       0     1        0        1         0       16
# 9                SWEENY PD       0     0        1        7        23       53
# 139           BELLVILLE PD       0     3        2        4        10       59
# 140           SEALY ISD PD       0     0        0        0         0        4
# 141           AUSTIN CO SO       0     3        3       20        52       65
# 142              WALLIS PD       0     0        0        4         6        4
# 143               SEALY PD       0     0        6       15        68      107
# 144      SURFSIDE BEACH PD       0     0        0        3         9        9
# 145        DANBURY PD (NR)       0     1        0        1         2        0
# 146        ANGLETON ISD PD       0     0        0        7         0       60
# 147  ALVIN COMM COLLEGE PD       0     0        0        0         1       22
# 148        OYSTER CREEK PD       0     1        0       18         9       22
# 282           BELLVILLE PD       0     8        0        5        16       43
# 283           SEALY ISD PD       0     0        0        0         1        3
# 284           AUSTIN CO SO       0     3        1        9        45       64
# 285              WALLIS PD       0     0        0        2         1        4
# 286               SEALY PD       0     0        4       18        35       69
# 287        OYSTER CREEK PD       0     0        1       14        13       27
# 288              MANVEL PD       1     0        2        6        40       59
# 289              SWEENY PD       0     2        0       13        13       77
# 290       WEST COLUMBIA PD       0     7        1       21         8       43
# 291        DANBURY PD (NR)       0     0        0        1         1        0
# 424           BELLVILLE PD       0     3        0       10         5       43
# 425           SEALY ISD PD       0     0        0        0         0        0
# 426           AUSTIN CO SO       0     6        0        8        48       36
# 427              WALLIS PD       0     0        0        5         1        4
# 428               SEALY PD       0     2        3        9        28       55
# 429              SWEENY PD       0     5        1        2        10       69
# 430       WEST COLUMBIA PD       0     2        0        5        23       69
# 431        OYSTER CREEK PD       0     0        1       15         6       16
# 432              MANVEL PD       0     3        0        9        32       36
# 433        DANBURY PD (NR)       1     0        0        1         0        0
# 566           BELLVILLE PD       0     3        1        8         2       38
# 567           SEALY ISD PD       0     0        0        0         0        1
# 568           AUSTIN CO SO       0     2        0       11        40       29
# 569               SEALY PD       0     0        2        9        36       73
# 570              WALLIS PD       0     0        0       10         2        6
# 571              SWEENY PD       0     1        3        4        12       59
# 572       WEST COLUMBIA PD       0     5        1        6        11       44
# 573        OYSTER CREEK PD       0     0        0       14         7       19
# 574              MANVEL PD       0     2        2        9        49       58
# 575      SURFSIDE BEACH PD       0     1        0        0         3       19
# 711           BELLVILLE PD       1     0        1       15        12       30
# 712           SEALY ISD PD       0     0        0        0         1        0
# 713           AUSTIN CO SO       1     3        1        9        18       44
# 714              WALLIS PD       1     2        0        4         7        4
# 715               SEALY PD       0     1        1        5        34       55
# 716        OYSTER CREEK PD       0     4        0        6         1       10
# 717              SWEENY PD       0     2        2        5        17       48
# 718       WEST COLUMBIA PD       0     1        0        3         2       19
# 719              MANVEL PD       0     5        2       10        20       64
# 720      SURFSIDE BEACH PD       0     1        1        4         2       19
#
#      Auto Theft  Total  Population  Year           County
# 0             0     73        4235  2015    Austin County
# 1             0      7           0  2015    Austin County
# 2             8    135       17499  2015    Austin County
# 3             0     13        1284  2015    Austin County
# 4             5    254        6336  2015    Austin County
# 5             0      3        1767  2015  Brazoria County
# 6             1     14           0  2015  Brazoria County
# 7             4     21         544  2015  Brazoria County
# 8             0     18           0  2015  Brazoria County
# 9             1     85        3780  2015  Brazoria County
# 139           2     80        4296  2016    Austin County
# 140           0      4           0  2016    Austin County
# 141          22    165       17650  2016    Austin County
# 142           1     15        1303  2016    Austin County
# 143           6    202        6469  2016    Austin County
# 144           2     23         557  2016  Brazoria County
# 145           0      4        1788  2016  Brazoria County
# 146           1     68           0  2016  Brazoria County
# 147           0     23           0  2016  Brazoria County
# 148           3     53        1136  2016  Brazoria County
# 282           0     72        4304  2017    Austin County
# 283           1      5           0  2017    Austin County
# 284          29    151       17798  2017    Austin County
# 285           0      7        1306  2017    Austin County
# 286          15    141        6555  2017    Austin County
# 287           3     58        1129  2017  Brazoria County
# 288           9    117        9756  2017  Brazoria County
# 289           2    107        3773  2017  Brazoria County
# 290           2     82        3938  2017  Brazoria County
# 291           0      2        1791  2017  Brazoria County
# 424           5     66        4257  2018    Austin County
# 425           0      0           0  2018    Austin County
# 426          16    114       17807  2018    Austin County
# 427           0     10        1304  2018    Austin County
# 428           8    105        6544  2018    Austin County
# 429           4     91        3753  2018  Brazoria County
# 430           4    103        3899  2018  Brazoria County
# 431           5     43        1163  2018  Brazoria County
# 432           6     86       11097  2018  Brazoria County
# 433           0      2        1777  2018  Brazoria County
# 566           0     52        4288  2019    Austin County
# 567           0      1           0  2019    Austin County
# 568          18    100       17806  2019    Austin County
# 569          11    131        6593  2019    Austin County
# 570           0     18        1322  2019    Austin County
# 571           1     80        3745  2019  Brazoria County
# 572           9     76        3881  2019  Brazoria County
# 573           3     43        1170  2019  Brazoria County
# 574          11    131       12721  2019  Brazoria County
# 575           2     25         594  2019  Brazoria County
# 711           5     64        4233  2020    Austin County
# 712           0      1           0  2020    Austin County
# 713          17     93       18095  2020    Austin County
# 714           3     21        1309  2020    Austin County
# 715           6    102        6484  2020    Austin County
# 716           4     25        1203  2020  Brazoria County
# 717           2     76        3716  2020  Brazoria County
# 718           2     27        3823  2020  Brazoria County
# 719           7    108       13971  2020  Brazoria County
# 720           8     35         591  2020  Brazoria County

# %%
# 2015 df
df_2015 = df.groupby('Year').get_group(2015)
df_2015.head()
# Out:
#      AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0  BELLVILLE PD       0     3        2        6        17       45
# 1  SEALY ISD PD       0     0        0        1         1        5
# 2  AUSTIN CO SO       0     3        2       13        48       61
# 3     WALLIS PD       0     0        0        0         3       10
# 4      SEALY PD       0     2        0       33        52      162
#
#    Auto Theft  Total  Population  Year         County
# 0           0     73        4235  2015  Austin County
# 1           0      7           0  2015  Austin County
# 2           8    135       17499  2015  Austin County
# 3           0     13        1284  2015  Austin County
# 4           5    254        6336  2015  Austin County

# %%
# 2016 df
df_2016 = df.groupby('Year').get_group(2016)
df_2016.head()
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 139  BELLVILLE PD       0     3        2        4        10       59
# 140  SEALY ISD PD       0     0        0        0         0        4
# 141  AUSTIN CO SO       0     3        3       20        52       65
# 142     WALLIS PD       0     0        0        4         6        4
# 143      SEALY PD       0     0        6       15        68      107
#
#      Auto Theft  Total  Population  Year         County
# 139           2     80        4296  2016  Austin County
# 140           0      4           0  2016  Austin County
# 141          22    165       17650  2016  Austin County
# 142           1     15        1303  2016  Austin County
# 143           6    202        6469  2016  Austin County

# %%
# 2017 df
df_2017 = df.groupby('Year').get_group(2017)
df_2017.head()
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 282  BELLVILLE PD       0     8        0        5        16       43
# 283  SEALY ISD PD       0     0        0        0         1        3
# 284  AUSTIN CO SO       0     3        1        9        45       64
# 285     WALLIS PD       0     0        0        2         1        4
# 286      SEALY PD       0     0        4       18        35       69
#
#      Auto Theft  Total  Population  Year         County
# 282           0     72        4304  2017  Austin County
# 283           1      5           0  2017  Austin County
# 284          29    151       17798  2017  Austin County
# 285           0      7        1306  2017  Austin County
# 286          15    141        6555  2017  Austin County

# %%
# 2018 df
df_2018 = df.groupby('Year').get_group(2018)
df_2018.head()
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 424  BELLVILLE PD       0     3        0       10         5       43
# 425  SEALY ISD PD       0     0        0        0         0        0
# 426  AUSTIN CO SO       0     6        0        8        48       36
# 427     WALLIS PD       0     0        0        5         1        4
# 428      SEALY PD       0     2        3        9        28       55
#
#      Auto Theft  Total  Population  Year         County
# 424           5     66        4257  2018  Austin County
# 425           0      0           0  2018  Austin County
# 426          16    114       17807  2018  Austin County
# 427           0     10        1304  2018  Austin County
# 428           8    105        6544  2018  Austin County

# %%
# 2019 df
df_2019 = df.groupby('Year').get_group(2019)
df_2019.head()
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 566  BELLVILLE PD       0     3        1        8         2       38
# 567  SEALY ISD PD       0     0        0        0         0        1
# 568  AUSTIN CO SO       0     2        0       11        40       29
# 569      SEALY PD       0     0        2        9        36       73
# 570     WALLIS PD       0     0        0       10         2        6
#
#      Auto Theft  Total  Population  Year         County
# 566           0     52        4288  2019  Austin County
# 567           0      1           0  2019  Austin County
# 568          18    100       17806  2019  Austin County
# 569          11    131        6593  2019  Austin County
# 570           0     18        1322  2019  Austin County

# %%
# 2020 df
df_2020 = df.groupby('Year').get_group(2020)
df_2020.head()
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 711  BELLVILLE PD       1     0        1       15        12       30
# 712  SEALY ISD PD       0     0        0        0         1        0
# 713  AUSTIN CO SO       1     3        1        9        18       44
# 714     WALLIS PD       1     2        0        4         7        4
# 715      SEALY PD       0     1        1        5        34       55
#
#      Auto Theft  Total  Population  Year         County
# 711           5     64        4233  2020  Austin County
# 712           0      1           0  2020  Austin County
# 713          17     93       18095  2020  Austin County
# 714           3     21        1309  2020  Austin County
# 715           6    102        6484  2020  Austin County

# %% [markdown]
# ### Finding how many agencies reported data per year

# %%
#Count the number of agencies reporting per county per year
agencies_count_per_year = df.groupby(["County", "Year"]).count()
agencies_count_per_year
# Out:
#                      AgencyName  Murder  Rape  Robbery  Assault  Burglary  \
# County         Year
# Austin County  2015           5       5     5        5        5         5
#                2016           5       5     5        5        5         5
#                2017           5       5     5        5        5         5
#                2018           5       5     5        5        5         5
#                2019           5       5     5        5        5         5
# ...                         ...     ...   ...      ...      ...       ...
# Wharton County 2016           3       3     3        3        3         3
#                2017           3       3     3        3        3         3
#                2018           3       3     3        3        3         3
#                2019           4       4     4        4        4         4
#                2020           4       4     4        4        4         4
#
#                      Larceny  Auto Theft  Total  Population
# County         Year
# Austin County  2015        5           5      5           5
#                2016        5           5      5           5
#                2017        5           5      5           5
#                2018        5           5      5           5
#                2019        5           5      5           5
# ...                      ...         ...    ...         ...
# Wharton County 2016        3           3      3           3
#                2017        3           3      3           3
#                2018        3           3      3           3
#                2019        4           4      4           4
#                2020        4           4      4           4
#
# [87 rows x 10 columns]

# %%
#Create new df to hold count
agencies_count_per_year_df = pd.DataFrame(agencies_count_per_year).reset_index()
agencies_count_per_year_df.head()
# Out:
#           County  Year  AgencyName  Murder  Rape  Robbery  Assault  Burglary  \
# 0  Austin County  2015           5       5     5        5        5         5
# 1  Austin County  2016           5       5     5        5        5         5
# 2  Austin County  2017           5       5     5        5        5         5
# 3  Austin County  2018           5       5     5        5        5         5
# 4  Austin County  2019           5       5     5        5        5         5
#
#    Larceny  Auto Theft  Total  Population
# 0        5           5      5           5
# 1        5           5      5           5
# 2        5           5      5           5
# 3        5           5      5           5
# 4        5           5      5           5

# %%
# Column names
agencies_count_per_year_df.columns
# Out:
# Index(['County', 'Year', 'AgencyName', 'Murder', 'Rape', 'Robbery', 'Assault',
#        'Burglary', 'Larceny', 'Auto Theft', 'Total', 'Population'],
#       dtype='object')

# %%
# Rename AgencyName coulumn to Agency count
agencies_count_per_year_df.rename(columns = {"AgencyName":"AgencyCount"}, inplace=True)
agencies_count_per_year_df.head()
# Out:
#           County  Year  AgencyCount  Murder  Rape  Robbery  Assault  Burglary  \
# 0  Austin County  2015            5       5     5        5        5         5
# 1  Austin County  2016            5       5     5        5        5         5
# 2  Austin County  2017            5       5     5        5        5         5
# 3  Austin County  2018            5       5     5        5        5         5
# 4  Austin County  2019            5       5     5        5        5         5
#
#    Larceny  Auto Theft  Total  Population
# 0        5           5      5           5
# 1        5           5      5           5
# 2        5           5      5           5
# 3        5           5      5           5
# 4        5           5      5           5

# %%
# Drop unnecessary columns
agencies_count_per_year_df = agencies_count_per_year_df.drop(columns=['Murder', 'Rape', 'Robbery', 'Assault',
       'Burglary', 'Larceny', 'Auto Theft', 'Total', 'Population'])
agencies_count_per_year_df.head()
# Out:
#           County  Year  AgencyCount
# 0  Austin County  2015            5
# 1  Austin County  2016            5
# 2  Austin County  2017            5
# 3  Austin County  2018            5
# 4  Austin County  2019            5

# %% [markdown]
# ### Crime Data by County

# %%
# groupby Counties
counties = df.groupby('County')
counties.head()
# Out:
#             AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0         BELLVILLE PD       0     3        2        6        17       45
# 1         SEALY ISD PD       0     0        0        1         1        5
# 2         AUSTIN CO SO       0     3        2       13        48       61
# 3            WALLIS PD       0     0        0        0         3       10
# 4             SEALY PD       0     2        0       33        52      162
# ..                 ...     ...   ...      ...      ...       ...      ...
# 412  SAN JACINTO CO SO       0    27        3       26       195      198
# 530      LIBERTY CO SO       2    46        4      125       237      333
# 554  SAN JACINTO CO SO       0    16        2       24       144      168
# 698  SAN JACINTO CO SO       0    26        1       17       115      173
# 843  SAN JACINTO CO SO       0    31        1        6       325      318
#
#      Auto Theft  Total  Population  Year              County
# 0             0     73        4235  2015       Austin County
# 1             0      7           0  2015       Austin County
# 2             8    135       17499  2015       Austin County
# 3             0     13        1284  2015       Austin County
# 4             5    254        6336  2015       Austin County
# ..          ...    ...         ...   ...                 ...
# 412          73    522       27895  2017  San Jacinto County
# 530          98    845       59062  2018      Liberty County
# 554          48    402       28457  2018  San Jacinto County
# 698          42    374       28832  2019  San Jacinto County
# 843          68    749       29039  2020  San Jacinto County
#
# [75 rows x 12 columns]

# %%
# Dropping AgencyName Column so only counties are listed
counties_df = df.drop(columns = ['AgencyName'])
counties_df
# Out:
#      Murder  Rape  Robbery  Assault  Burglary  Larceny  Auto Theft  Total  \
# 0         0     3        2        6        17       45           0     73
# 1         0     0        0        1         1        5           0      7
# 2         0     3        2       13        48       61           8    135
# 3         0     0        0        0         3       10           0     13
# 4         0     2        0       33        52      162           5    254
# ..      ...   ...      ...      ...       ...      ...         ...    ...
# 851       1     2        5       15        26       23           7     79
# 852       0     1        3       54        77      174          36    345
# 853       0     1        5       18        38      109          13    184
# 854       0     0        0        0         0        0           0      0
# 855       2     7        7       47        44      278          35    420
#
#      Population  Year          County
# 0          4235  2015   Austin County
# 1             0  2015   Austin County
# 2         17499  2015   Austin County
# 3          1284  2015   Austin County
# 4          6336  2015   Austin County
# ..          ...   ...             ...
# 851        7126  2020   Waller County
# 852       21310  2020  Wharton County
# 853        8612  2020  Wharton County
# 854           0  2020  Wharton County
# 855       11523  2020  Wharton County
#
# [856 rows x 11 columns]

# %%
# Reorder columns
new_column_order = ["County","Murder","Rape","Assault","Burglary","Larceny","Auto Theft","Total","Population","Year"]
counties_df = counties_df[new_column_order]
counties_df
# Out:
#              County  Murder  Rape  Assault  Burglary  Larceny  Auto Theft  \
# 0     Austin County       0     3        6        17       45           0
# 1     Austin County       0     0        1         1        5           0
# 2     Austin County       0     3       13        48       61           8
# 3     Austin County       0     0        0         3       10           0
# 4     Austin County       0     2       33        52      162           5
# ..              ...     ...   ...      ...       ...      ...         ...
# 851   Waller County       1     2       15        26       23           7
# 852  Wharton County       0     1       54        77      174          36
# 853  Wharton County       0     1       18        38      109          13
# 854  Wharton County       0     0        0         0        0           0
# 855  Wharton County       2     7       47        44      278          35
#
#      Total  Population  Year
# 0       73        4235  2015
# 1        7           0  2015
# 2      135       17499  2015
# 3       13        1284  2015
# 4      254        6336  2015
# ..     ...         ...   ...
# 851     79        7126  2020
# 852    345       21310  2020
# 853    184        8612  2020
# 854      0           0  2020
# 855    420       11523  2020
#
# [856 rows x 10 columns]

# %%
county_summary = counties_df.groupby(["County", "Year"]).sum()
county_summary
# Out:
#                      Murder  Rape  Assault  Burglary  Larceny  Auto Theft  \
# County         Year
# Austin County  2015       0     8       53       121      283          13
#                2016       0     6       43       136      239          31
#                2017       0    11       34        98      183          45
#                2018       0    11       32        82      138          29
#                2019       0     5       38        80      147          29
# ...                     ...   ...      ...       ...      ...         ...
# Wharton County 2016       1    23      132       217      815          63
#                2017       2    16      127       210      646          62
#                2018       3    17      111       163      527          39
#                2019       1    18      103       177      559          61
#                2020       2     9      119       159      561          84
#
#                      Total  Population
# County         Year
# Austin County  2015    482       29354
#                2016    466       29718
#                2017    376       29963
#                2018    295       29912
#                2019    302       30009
# ...                    ...         ...
# Wharton County 2016   1268       41398
#                2017   1086       41762
#                2018    868       41950
#                2019    944       41400
#                2020    949       41445
#
# [87 rows x 8 columns]

# %%
county_summary_df = pd.DataFrame(county_summary).reset_index()
county_summary_df.head(6)
# Out:
#           County  Year  Murder  Rape  Assault  Burglary  Larceny  Auto Theft  \
# 0  Austin County  2015       0     8       53       121      283          13
# 1  Austin County  2016       0     6       43       136      239          31
# 2  Austin County  2017       0    11       34        98      183          45
# 3  Austin County  2018       0    11       32        82      138          29
# 4  Austin County  2019       0     5       38        80      147          29
# 5  Austin County  2020       3     6       33        72      133          31
#
#    Total  Population
# 0    482       29354
# 1    466       29718
# 2    376       29963
# 3    295       29912
# 4    302       30009
# 5    281       30121

# %%
county_summary_df.dtypes
# Out:
# County        object
# Year           int64
# Murder         int64
# Rape           int64
# Assault        int64
# Burglary       int64
# Larceny        int64
# Auto Theft     int64
# Total          int64
# Population     int64
# dtype: object
