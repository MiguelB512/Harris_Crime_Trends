# %%
# Import dependencies
import os 
import pandas as pd
import matplotlib as plt
import regex as re

# %%
# Import CSV file
df = pd.read_csv('Resources/Crime_Index_Greater_Houston_Area_2015_2020.csv')
df
# Out:
#           AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0       BELLVILLE PD       0     3        2        6        17       45
# 1       SEALY ISD PD       0     0        0        1         1        5
# 2       AUSTIN CO SO       0     3        2       13        48       61
# 3          WALLIS PD       0     0        0        0         3       10
# 4           SEALY PD       0     2        0       33        52      162
# ..               ...     ...   ...      ...      ...       ...      ...
# 851  PRAIRIE VIEW PD       1     2        5       15        26       23
# 852    WHARTON CO SO       0     1        3       54        77      174
# 853       WHARTON PD       0     1        5       18        38      109
# 854   WHARTON ISD PD       0     0        0        0         0        0
# 855      EL CAMPO PD       2     7        7       47        44      278
#
#      Auto Theft  Total  Population  Year          County
# 0             0     73        4235  2015   Austin County
# 1             0      7           0  2015   Austin County
# 2             8    135       17499  2015   Austin County
# 3             0     13        1284  2015   Austin County
# 4             5    254        6336  2015   Austin County
# ..          ...    ...         ...   ...             ...
# 851           7     79        7126  2020   Waller County
# 852          36    345       21310  2020  Wharton County
# 853          13    184        8612  2020  Wharton County
# 854           0      0           0  2020  Wharton County
# 855          35    420       11523  2020  Wharton County
#
# [856 rows x 12 columns]

# %%
# Data types
df.dtypes
# Out:
# AgencyName    object
# Murder         int64
# Rape           int64
# Robbery        int64
# Assault        int64
# Burglary       int64
# Larceny        int64
# Auto Theft     int64
# Total          int64
# Population     int64
# Year           int64
# County        object
# dtype: object

# %%
df = df.astype({"Year":'object'})
df.dtypes
# Out:
# AgencyName    object
# Murder         int64
# Rape           int64
# Robbery        int64
# Assault        int64
# Burglary       int64
# Larceny        int64
# Auto Theft     int64
# Total          int64
# Population     int64
# Year          object
# County        object
# dtype: object

# %%
# .groupby Year
year_df = df.groupby('Year')
year_df.head(5)
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0    BELLVILLE PD       0     3        2        6        17       45
# 1    SEALY ISD PD       0     0        0        1         1        5
# 2    AUSTIN CO SO       0     3        2       13        48       61
# 3       WALLIS PD       0     0        0        0         3       10
# 4        SEALY PD       0     2        0       33        52      162
# 139  BELLVILLE PD       0     3        2        4        10       59
# 140  SEALY ISD PD       0     0        0        0         0        4
# 141  AUSTIN CO SO       0     3        3       20        52       65
# 142     WALLIS PD       0     0        0        4         6        4
# 143      SEALY PD       0     0        6       15        68      107
# 282  BELLVILLE PD       0     8        0        5        16       43
# 283  SEALY ISD PD       0     0        0        0         1        3
# 284  AUSTIN CO SO       0     3        1        9        45       64
# 285     WALLIS PD       0     0        0        2         1        4
# 286      SEALY PD       0     0        4       18        35       69
# 424  BELLVILLE PD       0     3        0       10         5       43
# 425  SEALY ISD PD       0     0        0        0         0        0
# 426  AUSTIN CO SO       0     6        0        8        48       36
# 427     WALLIS PD       0     0        0        5         1        4
# 428      SEALY PD       0     2        3        9        28       55
# 566  BELLVILLE PD       0     3        1        8         2       38
# 567  SEALY ISD PD       0     0        0        0         0        1
# 568  AUSTIN CO SO       0     2        0       11        40       29
# 569      SEALY PD       0     0        2        9        36       73
# 570     WALLIS PD       0     0        0       10         2        6
# 711  BELLVILLE PD       1     0        1       15        12       30
# 712  SEALY ISD PD       0     0        0        0         1        0
# 713  AUSTIN CO SO       1     3        1        9        18       44
# 714     WALLIS PD       1     2        0        4         7        4
# 715      SEALY PD       0     1        1        5        34       55
#
#      Auto Theft  Total  Population  Year         County
# 0             0     73        4235  2015  Austin County
# 1             0      7           0  2015  Austin County
# 2             8    135       17499  2015  Austin County
# 3             0     13        1284  2015  Austin County
# 4             5    254        6336  2015  Austin County
# 139           2     80        4296  2016  Austin County
# 140           0      4           0  2016  Austin County
# 141          22    165       17650  2016  Austin County
# 142           1     15        1303  2016  Austin County
# 143           6    202        6469  2016  Austin County
# 282           0     72        4304  2017  Austin County
# 283           1      5           0  2017  Austin County
# 284          29    151       17798  2017  Austin County
# 285           0      7        1306  2017  Austin County
# 286          15    141        6555  2017  Austin County
# 424           5     66        4257  2018  Austin County
# 425           0      0           0  2018  Austin County
# 426          16    114       17807  2018  Austin County
# 427           0     10        1304  2018  Austin County
# 428           8    105        6544  2018  Austin County
# 566           0     52        4288  2019  Austin County
# 567           0      1           0  2019  Austin County
# 568          18    100       17806  2019  Austin County
# 569          11    131        6593  2019  Austin County
# 570           0     18        1322  2019  Austin County
# 711           5     64        4233  2020  Austin County
# 712           0      1           0  2020  Austin County
# 713          17     93       18095  2020  Austin County
# 714           3     21        1309  2020  Austin County
# 715           6    102        6484  2020  Austin County

# %%
# 2015 df
df_2015 = df.groupby('Year').get_group(2015)
df_2015.head()
# Out:
#      AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0  BELLVILLE PD       0     3        2        6        17       45
# 1  SEALY ISD PD       0     0        0        1         1        5
# 2  AUSTIN CO SO       0     3        2       13        48       61
# 3     WALLIS PD       0     0        0        0         3       10
# 4      SEALY PD       0     2        0       33        52      162
#
#    Auto Theft  Total  Population  Year         County
# 0           0     73        4235  2015  Austin County
# 1           0      7           0  2015  Austin County
# 2           8    135       17499  2015  Austin County
# 3           0     13        1284  2015  Austin County
# 4           5    254        6336  2015  Austin County

# %%
# 2016 df
df_2016 = df.groupby('Year').get_group(2016)
df_2016.head()
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 139  BELLVILLE PD       0     3        2        4        10       59
# 140  SEALY ISD PD       0     0        0        0         0        4
# 141  AUSTIN CO SO       0     3        3       20        52       65
# 142     WALLIS PD       0     0        0        4         6        4
# 143      SEALY PD       0     0        6       15        68      107
#
#      Auto Theft  Total  Population  Year         County
# 139           2     80        4296  2016  Austin County
# 140           0      4           0  2016  Austin County
# 141          22    165       17650  2016  Austin County
# 142           1     15        1303  2016  Austin County
# 143           6    202        6469  2016  Austin County

# %%
# 2017 df
df_2017 = df.groupby('Year').get_group(2017)
df_2017.head()
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 282  BELLVILLE PD       0     8        0        5        16       43
# 283  SEALY ISD PD       0     0        0        0         1        3
# 284  AUSTIN CO SO       0     3        1        9        45       64
# 285     WALLIS PD       0     0        0        2         1        4
# 286      SEALY PD       0     0        4       18        35       69
#
#      Auto Theft  Total  Population  Year         County
# 282           0     72        4304  2017  Austin County
# 283           1      5           0  2017  Austin County
# 284          29    151       17798  2017  Austin County
# 285           0      7        1306  2017  Austin County
# 286          15    141        6555  2017  Austin County

# %%
# 2018 df
df_2018 = df.groupby('Year').get_group(2018)
df_2018.head()
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 424  BELLVILLE PD       0     3        0       10         5       43
# 425  SEALY ISD PD       0     0        0        0         0        0
# 426  AUSTIN CO SO       0     6        0        8        48       36
# 427     WALLIS PD       0     0        0        5         1        4
# 428      SEALY PD       0     2        3        9        28       55
#
#      Auto Theft  Total  Population  Year         County
# 424           5     66        4257  2018  Austin County
# 425           0      0           0  2018  Austin County
# 426          16    114       17807  2018  Austin County
# 427           0     10        1304  2018  Austin County
# 428           8    105        6544  2018  Austin County

# %%
# 2019 df
df_2019 = df.groupby('Year').get_group(2019)
df_2019.head()
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 566  BELLVILLE PD       0     3        1        8         2       38
# 567  SEALY ISD PD       0     0        0        0         0        1
# 568  AUSTIN CO SO       0     2        0       11        40       29
# 569      SEALY PD       0     0        2        9        36       73
# 570     WALLIS PD       0     0        0       10         2        6
#
#      Auto Theft  Total  Population  Year         County
# 566           0     52        4288  2019  Austin County
# 567           0      1           0  2019  Austin County
# 568          18    100       17806  2019  Austin County
# 569          11    131        6593  2019  Austin County
# 570           0     18        1322  2019  Austin County

# %%
# 2020 df
df_2020 = df.groupby('Year').get_group(2020)
df_2020.head()
# Out:
#        AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 711  BELLVILLE PD       1     0        1       15        12       30
# 712  SEALY ISD PD       0     0        0        0         1        0
# 713  AUSTIN CO SO       1     3        1        9        18       44
# 714     WALLIS PD       1     2        0        4         7        4
# 715      SEALY PD       0     1        1        5        34       55
#
#      Auto Theft  Total  Population  Year         County
# 711           5     64        4233  2020  Austin County
# 712           0      1           0  2020  Austin County
# 713          17     93       18095  2020  Austin County
# 714           3     21        1309  2020  Austin County
# 715           6    102        6484  2020  Austin County

# %%
agencies_count_per_year = df.groupby("County")['Year'].value_counts()
agencies_count_per_year
# Out:
# County         Year
# Austin County  2015    5
#                2016    5
#                2017    5
#                2018    5
#                2019    5
# Name: Year, dtype: int64

# %%
agencies_count_per_year_df = pd.DataFrame(agencies_count_per_year)
agencies_count_per_year_df
# Out:
#                      Year
# County         Year
# Austin County  2015     5
#                2016     5
#                2017     5
#                2018     5
#                2019     5
# ...                   ...
# Wharton County 2020     4
#                2015     3
#                2016     3
#                2017     3
#                2018     3
#
# [87 rows x 1 columns]

# %%
# groupby Counties
counties = df.groupby('County')

# %%
counties.head()
# Out:
#             AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0         BELLVILLE PD       0     3        2        6        17       45
# 1         SEALY ISD PD       0     0        0        1         1        5
# 2         AUSTIN CO SO       0     3        2       13        48       61
# 3            WALLIS PD       0     0        0        0         3       10
# 4             SEALY PD       0     2        0       33        52      162
# ..                 ...     ...   ...      ...      ...       ...      ...
# 412  SAN JACINTO CO SO       0    27        3       26       195      198
# 530      LIBERTY CO SO       2    46        4      125       237      333
# 554  SAN JACINTO CO SO       0    16        2       24       144      168
# 698  SAN JACINTO CO SO       0    26        1       17       115      173
# 843  SAN JACINTO CO SO       0    31        1        6       325      318
#
#      Auto Theft  Total  Population  Year              County
# 0             0     73        4235  2015       Austin County
# 1             0      7           0  2015       Austin County
# 2             8    135       17499  2015       Austin County
# 3             0     13        1284  2015       Austin County
# 4             5    254        6336  2015       Austin County
# ..          ...    ...         ...   ...                 ...
# 412          73    522       27895  2017  San Jacinto County
# 530          98    845       59062  2018      Liberty County
# 554          48    402       28457  2018  San Jacinto County
# 698          42    374       28832  2019  San Jacinto County
# 843          68    749       29039  2020  San Jacinto County
#
# [75 rows x 12 columns]

# %%
# Dropping AgencyName Column so only counties are listed
counties_df = df.drop(columns = ['AgencyName'])
counties_df
# Out:
#      Murder  Rape  Robbery  Assault  Burglary  Larceny  Auto Theft  Total  \
# 0         0     3        2        6        17       45           0     73
# 1         0     0        0        1         1        5           0      7
# 2         0     3        2       13        48       61           8    135
# 3         0     0        0        0         3       10           0     13
# 4         0     2        0       33        52      162           5    254
# ..      ...   ...      ...      ...       ...      ...         ...    ...
# 851       1     2        5       15        26       23           7     79
# 852       0     1        3       54        77      174          36    345
# 853       0     1        5       18        38      109          13    184
# 854       0     0        0        0         0        0           0      0
# 855       2     7        7       47        44      278          35    420
#
#      Population  Year          County
# 0          4235  2015   Austin County
# 1             0  2015   Austin County
# 2         17499  2015   Austin County
# 3          1284  2015   Austin County
# 4          6336  2015   Austin County
# ..          ...   ...             ...
# 851        7126  2020   Waller County
# 852       21310  2020  Wharton County
# 853        8612  2020  Wharton County
# 854           0  2020  Wharton County
# 855       11523  2020  Wharton County
#
# [856 rows x 11 columns]

# %%
# Reorder columns
new_column_order = ["County","Murder","Rape","Assault","Burglary","Larceny","Auto Theft","Total","Population","Year"]
counties_df = counties_df[new_column_order]
counties_df
# Out:
#              County  Murder  Rape  Assault  Burglary  Larceny  Auto Theft  \
# 0     Austin County       0     3        6        17       45           0
# 1     Austin County       0     0        1         1        5           0
# 2     Austin County       0     3       13        48       61           8
# 3     Austin County       0     0        0         3       10           0
# 4     Austin County       0     2       33        52      162           5
# ..              ...     ...   ...      ...       ...      ...         ...
# 851   Waller County       1     2       15        26       23           7
# 852  Wharton County       0     1       54        77      174          36
# 853  Wharton County       0     1       18        38      109          13
# 854  Wharton County       0     0        0         0        0           0
# 855  Wharton County       2     7       47        44      278          35
#
#      Total  Population  Year
# 0       73        4235  2015
# 1        7           0  2015
# 2      135       17499  2015
# 3       13        1284  2015
# 4      254        6336  2015
# ..     ...         ...   ...
# 851     79        7126  2020
# 852    345       21310  2020
# 853    184        8612  2020
# 854      0           0  2020
# 855    420       11523  2020
#
# [856 rows x 10 columns]

# %%
county_summary_df = counties_df.groupby(["County", "Year"]).sum()
county_summary_df.head(20)
# Out:
#                       Murder  Rape  Assault  Burglary  Larceny  Auto Theft  \
# County          Year
# Austin County   2015       0     8       53       121      283          13
#                 2016       0     6       43       136      239          31
#                 2017       0    11       34        98      183          45
#                 2018       0    11       32        82      138          29
#                 2019       0     5       38        80      147          29
#                 2020       3     6       33        72      133          31
# Brazoria County 2015       4   114      352      1149     4475         359
#                 2016       8   110      395       996     4443         404
#                 2017      10   113      437       947     4111         370
#                 2018       4   131      377       800     4241         390
#                 2019      20   246      800      2004     9518         944
#                 2020      13   118      456       708     4302         505
# Brazos County   2015       9   131      447       969     4628         244
#                 2016       5   129      474       972     4354         288
#                 2017       6   124      399       752     4011         267
#                 2018       4   150      395       784     4087         330
#                 2019       5   177      373       841     3501         355
#                 2020       9   184      468       675     3494         402
# Chambers County 2015       3    12       95       144      591         112
#                 2016       3    19      109       149      621          76
#
#                       Total  Population
# County          Year
# Austin County   2015    482       29354
#                 2016    466       29718
#                 2017    376       29963
#                 2018    295       29912
#                 2019    302       30009
#                 2020    281       30121
# Brazoria County 2015   6555      350739
#                 2016   6511      358003
#                 2017   6079      367132
#                 2018   6050      373587
#                 2019  13798      763856
#                 2020   6210      386756
# Brazos County   2015   6533      213128
#                 2016   6373      218486
#                 2017   5679      224600
#                 2018   5833      226375
#                 2019   5359      229532
#                 2020   5312      232487
# Chambers County 2015    971       34701
#                 2016    995       35244
