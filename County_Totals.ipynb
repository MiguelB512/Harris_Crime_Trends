# %% [markdown]
# # Grouping and Summing counties to get totals

# %%
# Import dependencies
import os 
import pandas as pd
import matplotlib as plt
import regex as re
import numpy as np
from sqlalchemy import create_engine
import psycopg2
from scipy.stats import poisson

# %%
# SQL dependencies
from config import db_password
db_string = f"postgresql://bhmcd:{db_password}@crime-analysis.cnoedyl0m22c.us-east-2.rds.amazonaws.com:5432/Crime_AnalysisDB"
engine = create_engine(db_string)

# %%
# Import CSV file
df = pd.read_csv('Resources/CSV/Crime_Index_Greater_Houston_Area_2015_2020.csv')
df.head(10)
# Out:
#               AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0           BELLVILLE PD       0     3        2        6        17       45
# 1           SEALY ISD PD       0     0        0        1         1        5
# 2           AUSTIN CO SO       0     3        2       13        48       61
# 3              WALLIS PD       0     0        0        0         3       10
# 4               SEALY PD       0     2        0       33        52      162
# 5        DANBURY PD (NR)       0     1        0        0         0        2
# 6  ALVIN COMM COLLEGE PD       0     0        0        0         0       13
# 7      SURFSIDE BEACH PD       0     0        0        2         4       11
# 8        ANGLETON ISD PD       0     1        0        1         0       16
# 9              SWEENY PD       0     0        1        7        23       53
#
#    Auto Theft  Total  Population  Year           County
# 0           0     73        4235  2015    Austin County
# 1           0      7           0  2015    Austin County
# 2           8    135       17499  2015    Austin County
# 3           0     13        1284  2015    Austin County
# 4           5    254        6336  2015    Austin County
# 5           0      3        1767  2015  Brazoria County
# 6           1     14           0  2015  Brazoria County
# 7           4     21         544  2015  Brazoria County
# 8           0     18           0  2015  Brazoria County
# 9           1     85        3780  2015  Brazoria County

# %%
# Setting column names to lowercase
df.columns= df.columns.str.lower()

# %%
# Get number of value counts to divide population
df.county.value_counts()
# Out:
# Harris County         265
# Brazoria County       131
# Galveston County      101
# Montgomery County      74
# Fort Bend County       66
# Waller County          35
# Austin County          30
# Matagorda County       26
# Brazos County          24
# Polk County            24
# Liberty County         23
# Wharton County         20
# Chambers County        18
# Grimes County          12
# Walker County          12
# Washington County      12
# San Jacinto County      6
# Name: county, dtype: int64

# %%
# Check types
df.dtypes
# Out:
# agencyname    object
# murder         int64
# rape           int64
# robbery        int64
# assault        int64
# burglary       int64
# larceny        int64
# auto theft     int64
# total          int64
# population     int64
# year           int64
# county        object
# dtype: object

# %% [markdown]
# ## Grouping data by county and summing

# %%
# Group crimes by county and sum
county_sum_df = df.groupby('county').sum()
county_sum_df['population'] = county_sum_df['population'].div(6).map('{:.0f}'.format)
county_sum_df.head(10)
# Out:
#                   murder   rape  robbery  assault  burglary  larceny  \
# county
# Austin County          3     47       29      233       589     1123
# Brazoria County       49    709      696     2417      5602    26331
# Brazos County         38    895      646     2556      4993    24075
# Chambers County       14     92       75      484       828     3314
# Fort Bend County     107   1149     1696     5471      8776    41467
# Galveston County     117   1373     1283     3026      8005    35329
# Grimes County         10     55       42      279       743     1218
# Harris County       2536  13361    76016   123097    165783   656872
# Liberty County        29    277      131     1160      1878     5812
# Matagorda County      20    148      122      638      1601     4798
#
#                   auto theft    total population    year
# county
# Austin County            178     2202      29846   60525
# Brazoria County         2500    38304     369691  264296
# Brazos County           1886    35089     224101   48420
# Chambers County          493     5300      37318   36315
# Fort Bend County        3279    61945     739020  133155
# Galveston County        4266    53399     347699  203766
# Grimes County            227     2574      28081   24210
# Harris County         124937  1162602    4707136  534647
# Liberty County          1043    10330      74284   46403
# Matagorda County         240     7567      36670   52459

# %%
# Drop the year column
county_sum_df.drop(['year'], axis = 1, inplace = True)
county_sum_df.head()
# Out:
#                   murder  rape  robbery  assault  burglary  larceny  \
# county
# Austin County          3    47       29      233       589     1123
# Brazoria County       49   709      696     2417      5602    26331
# Brazos County         38   895      646     2556      4993    24075
# Chambers County       14    92       75      484       828     3314
# Fort Bend County     107  1149     1696     5471      8776    41467
#
#                   auto theft  total population
# county
# Austin County            178   2202      29846
# Brazoria County         2500  38304     369691
# Brazos County           1886  35089     224101
# Chambers County          493   5300      37318
# Fort Bend County        3279  61945     739020

# %%
# Check final DF
county_sum_df.head()
# Out:
#                   murder  rape  robbery  assault  burglary  larceny  \
# county
# Austin County          3    47       29      233       589     1123
# Brazoria County       49   709      696     2417      5602    26331
# Brazos County         38   895      646     2556      4993    24075
# Chambers County       14    92       75      484       828     3314
# Fort Bend County     107  1149     1696     5471      8776    41467
#
#                   auto theft  total population
# county
# Austin County            178   2202      29846
# Brazoria County         2500  38304     369691
# Brazos County           1886  35089     224101
# Chambers County          493   5300      37318
# Fort Bend County        3279  61945     739020

# %%
# Export County Summary to CSV
county_sum_df.to_csv('Resources/CSV/county_totals.csv', index=True)

# %%
# Export to SQL DB
county_sum_df.to_sql(name='county_totals', con=engine, index=True, if_exists='replace')
# Out:
# 17

# %% [markdown]
# ## Group and sum all texas counties

# %%
# Import CSV file
texas_county_sum_df = pd.read_csv('Resources/CSV/Texas-Crime-Index-2015-2020.csv')
texas_county_sum_df
# Out:
#                 AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0             FRANKSTON PD       0     2        1        6        14       31
# 1           ANDERSON CO SO       7    11        3       52       174      184
# 2             PALESTINE PD       2    25       18      137       131      534
# 3            ANDREWS CO SO       0     6        2        8        12       68
# 4               ANDREWS PD       0    12       10       56        48      245
# ...                    ...     ...   ...      ...      ...       ...      ...
# 6207              OLNEY PD       0     2        0       11        61       21
# 6208           YOUNG CO SO       0     4        0        4         7       14
# 6209          ZAPATA CO SO       0     0        3       13        36       72
# 6210          ZAVALA CO SO       1     1        0        9        12       24
# 6211  CRYSTAL CITY PD (NR)       0     0        0        7        13       15
#
#       Auto Theft  Total  Population  Year           County
# 0              2     56        1174  2015  Anderson County
# 1             25    456       38087  2015  Anderson County
# 2             48    895       18299  2015  Anderson County
# 3             20    116        4413  2015   Andrews County
# 4             31    402       13835  2015   Andrews County
# ...          ...    ...         ...   ...              ...
# 6207           4     99        3080  2020     Young County
# 6208           2     31        6220  2020     Young County
# 6209           0    124       14142  2020    Zapata County
# 6210           8     55        4655  2020    Zavala County
# 6211           0     35        7158  2020    Zavala County
#
# [6212 rows x 12 columns]

# %%
# Setting column names to lowercase
texas_county_sum_df.columns= texas_county_sum_df.columns.str.lower()

# %%
# Sum all texas counties in one DF
texas_county_sum_df = texas_county_sum_df.groupby('county').sum()
texas_county_sum_df['population'] = texas_county_sum_df['population'].div(6).map('{:.0f}'.format)
texas_county_sum_df
# Out:
#                  murder  rape  robbery  assault  burglary  larceny  \
# county
# Anderson County      20   153       98      890      1511     3271
# Andrews County        3    84       21      359       370     1491
# Angelina County      18   237      239     1211      3702     9420
# Aransas County       12   130       57      734      2088     4826
# Archer County         0     7        1       31        34       95
# ...                 ...   ...      ...      ...       ...      ...
# Wood County           4   137       19      281       856     1765
# Yoakum County         0    19        0       31       131      336
# Young County          5    46       19      120       356      761
# Zapata County         1     2        9       71       161      311
# Zavala County         1    18       10      182       550      673
#
#                  auto theft  total population   year
# county
# Anderson County         447   6390      57500  36315
# Andrews County          200   2528      18508  24210
# Angelina County         937  15764      87485  66582
# Aransas County          366   8213      32674  48420
# Archer County            18    186       3472  12105
# ...                     ...    ...        ...    ...
# Wood County             230   3292      45169  64564
# Yoakum County            40    557       8625  24210
# Young County             84   1391      18033  36315
# Zapata County            12    567       7112   6054
# Zavala County            57   1491      16866  28245
#
# [254 rows x 10 columns]

# %%
# Export County Summary to CSV
texas_county_sum_df.to_csv('Resources/CSV/texas_county_totals.csv', index=True)

# %%
# Export to SQL DB
texas_county_sum_df.to_sql(name='texas_county_totals', con=engine, index=True, if_exists='replace')
# Out:
# 254
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\donmc\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\donmc\anaconda3\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\donmc\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\donmc\anaconda3\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
