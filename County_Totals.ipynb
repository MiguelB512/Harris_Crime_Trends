# %% [markdown]
# # Grouping and Summing counties to get totals

# %%
# Import dependencies
import os 
import pandas as pd
import matplotlib as plt
import regex as re
import numpy as np
from sqlalchemy import create_engine
import psycopg2
from scipy.stats import poisson

# %%
# SQL dependencies
from config import db_password
db_string = f"postgresql://bhmcd:{db_password}@crime-analysis.cnoedyl0m22c.us-east-2.rds.amazonaws.com:5432/Crime_AnalysisDB"
engine = create_engine(db_string)

# %%
# Import CSV file
df = pd.read_csv('Resources/CSV/houston_area_crime_data.csv')
df.head(10)
# Out:
#             County  Year  Agency_Count  Murder  Rape  Assault  Burglary  \
# 0    Austin County  2015             5       0     8       53       121
# 1    Austin County  2016             5       0     6       43       136
# 2    Austin County  2017             5       0    11       34        98
# 3    Austin County  2018             5       0    11       32        82
# 4    Austin County  2019             5       0     5       38        80
# 5    Austin County  2020             5       3     6       33        72
# 6  Brazoria County  2015            21       4   114      352      1149
# 7  Brazoria County  2016            22       8   110      395       996
# 8  Brazoria County  2017            22      10   113      437       947
# 9  Brazoria County  2018            21       4   131      377       800
#
#    Larceny  Auto_Theft  Violent_Offenses  NonViolent_Offenses  Total_Crime  \
# 0      283          13                61                  417          482
# 1      239          31                49                  406          466
# 2      183          45                45                  326          376
# 3      138          29                43                  249          295
# 4      147          29                43                  256          302
# 5      133          31                42                  236          281
# 6     4475         359               470                 5983         6555
# 7     4443         404               513                 5843         6511
# 8     4111         370               560                 5428         6079
# 9     4241         390               512                 5431         6050
#
#    Population
# 0       29354
# 1       29718
# 2       29963
# 3       29912
# 4       30009
# 5       30121
# 6      350739
# 7      358003
# 8      367132
# 9      373587

# %%
# Setting column names to lowercase
df.columns= df.columns.str.lower()

# %%
# Get number of value counts to divide population
df.county.value_counts()
# Out:
# Austin County         6
# Matagorda County      6
# Washington County     6
# Waller County         6
# Walker County         6
# San Jacinto County    6
# Polk County           6
# Montgomery County     6
# Liberty County        6
# Brazoria County       6
# Harris County         6
# Grimes County         6
# Galveston County      6
# Fort Bend County      6
# Chambers County       6
# Brazos County         6
# Wharton County        6
# Name: county, dtype: int64

# %%
# Check types
df.dtypes
# Out:
# county                 object
# year                    int64
# agency_count            int64
# murder                  int64
# rape                    int64
# assault                 int64
# burglary                int64
# larceny                 int64
# auto_theft              int64
# violent_offenses        int64
# nonviolent_offenses     int64
# total_crime             int64
# population              int64
# dtype: object

# %% [markdown]
# ## Grouping data by county and summing

# %%
# Group crimes by county and sum
houston_county_sum_df = df.groupby('county').sum()
houston_county_sum_df['population'] = houston_county_sum_df['population'].div(6).map('{:.0f}'.format)
houston_county_sum_df.head(10)
# Out:
#                    year  agency_count  murder   rape  assault  burglary  \
# county
# Austin County     12105            30       3     47      233       589
# Brazoria County   12105           131      49    709     2417      5602
# Brazos County     12105            24      38    895     2556      4993
# Chambers County   12105            18      14     92      484       828
# Fort Bend County  12105            66     107   1149     5471      8776
# Galveston County  12105           101     117   1373     3026      8005
# Grimes County     12105            12      10     55      279       743
# Harris County     12105           265    2536  13361   123097    165783
# Liberty County    12105            23      29    277     1160      1878
# Matagorda County  12105            26      20    148      638      1601
#
#                   larceny  auto_theft  violent_offenses  nonviolent_offenses  \
# county
# Austin County        1123         178               283                 1890
# Brazoria County     26331        2500              3175                34433
# Brazos County       24075        1886              3489                30954
# Chambers County      3314         493               590                 4635
# Fort Bend County    41467        3279              6727                53522
# Galveston County    35329        4266              4516                47600
# Grimes County        1218         227               344                 2188
# Harris County      656872      124937            138994               947592
# Liberty County       5812        1043              1466                 8733
# Matagorda County     4798         240               806                 6639
#
#                   total_crime population
# county
# Austin County            2202      29846
# Brazoria County         38304     369691
# Brazos County           35089     224101
# Chambers County          5300      37318
# Fort Bend County        61945     739020
# Galveston County        53399     347699
# Grimes County            2574      28081
# Harris County         1162602    4707136
# Liberty County          10330      74284
# Matagorda County         7567      36670

# %%
# Rename total_crime column
houston_county_sum_df.rename(columns={'total_crime':'total_crimes'}, inplace=True)

# %%
# Drop the year column
houston_county_sum_df.drop(['year'], axis = 1, inplace = True)
houston_county_sum_df.head()
# Out:
#                   agency_count  murder  rape  assault  burglary  larceny  \
# county
# Austin County               30       3    47      233       589     1123
# Brazoria County            131      49   709     2417      5602    26331
# Brazos County               24      38   895     2556      4993    24075
# Chambers County             18      14    92      484       828     3314
# Fort Bend County            66     107  1149     5471      8776    41467
#
#                   auto_theft  violent_offenses  nonviolent_offenses  \
# county
# Austin County            178               283                 1890
# Brazoria County         2500              3175                34433
# Brazos County           1886              3489                30954
# Chambers County          493               590                 4635
# Fort Bend County        3279              6727                53522
#
#                   total_crimes population
# county
# Austin County             2202      29846
# Brazoria County          38304     369691
# Brazos County            35089     224101
# Chambers County           5300      37318
# Fort Bend County         61945     739020

# %%
# Remove index column name
houston_county_sum_df.index.name = None

# %%
# Check final DF
houston_county_sum_df.head(10)
# Out:
#                   agency_count  murder   rape  assault  burglary  larceny  \
# Austin County               30       3     47      233       589     1123
# Brazoria County            131      49    709     2417      5602    26331
# Brazos County               24      38    895     2556      4993    24075
# Chambers County             18      14     92      484       828     3314
# Fort Bend County            66     107   1149     5471      8776    41467
# Galveston County           101     117   1373     3026      8005    35329
# Grimes County               12      10     55      279       743     1218
# Harris County              265    2536  13361   123097    165783   656872
# Liberty County              23      29    277     1160      1878     5812
# Matagorda County            26      20    148      638      1601     4798
#
#                   auto_theft  violent_offenses  nonviolent_offenses  \
# Austin County            178               283                 1890
# Brazoria County         2500              3175                34433
# Brazos County           1886              3489                30954
# Chambers County          493               590                 4635
# Fort Bend County        3279              6727                53522
# Galveston County        4266              4516                47600
# Grimes County            227               344                 2188
# Harris County         124937            138994               947592
# Liberty County          1043              1466                 8733
# Matagorda County         240               806                 6639
#
#                   total_crimes population
# Austin County             2202      29846
# Brazoria County          38304     369691
# Brazos County            35089     224101
# Chambers County           5300      37318
# Fort Bend County         61945     739020
# Galveston County         53399     347699
# Grimes County             2574      28081
# Harris County          1162602    4707136
# Liberty County           10330      74284
# Matagorda County          7567      36670

# %%
# Export County Summary to CSV
houston_county_sum_df.to_csv('Resources/CSV/houston_county_totals.csv', index=True)

# %%
# Export to SQL DB
houston_county_sum_df.to_sql(name='houston_county_totals', con=engine, index=True, if_exists='replace')
# Out:
# 17

# %% [markdown]
# ## Group and sum all texas counties

# %%
# Import CSV file
texas_county_sum_df = pd.read_csv('Resources/CSV/Texas-Crime-Index-2015-2020.csv')
texas_county_sum_df
# Out:
#                 AgencyName  Murder  Rape  Robbery  Assault  Burglary  Larceny  \
# 0             FRANKSTON PD       0     2        1        6        14       31
# 1           ANDERSON CO SO       7    11        3       52       174      184
# 2             PALESTINE PD       2    25       18      137       131      534
# 3            ANDREWS CO SO       0     6        2        8        12       68
# 4               ANDREWS PD       0    12       10       56        48      245
# ...                    ...     ...   ...      ...      ...       ...      ...
# 6207              OLNEY PD       0     2        0       11        61       21
# 6208           YOUNG CO SO       0     4        0        4         7       14
# 6209          ZAPATA CO SO       0     0        3       13        36       72
# 6210          ZAVALA CO SO       1     1        0        9        12       24
# 6211  CRYSTAL CITY PD (NR)       0     0        0        7        13       15
#
#       Auto Theft  Total  Population  Year           County
# 0              2     56        1174  2015  Anderson County
# 1             25    456       38087  2015  Anderson County
# 2             48    895       18299  2015  Anderson County
# 3             20    116        4413  2015   Andrews County
# 4             31    402       13835  2015   Andrews County
# ...          ...    ...         ...   ...              ...
# 6207           4     99        3080  2020     Young County
# 6208           2     31        6220  2020     Young County
# 6209           0    124       14142  2020    Zapata County
# 6210           8     55        4655  2020    Zavala County
# 6211           0     35        7158  2020    Zavala County
#
# [6212 rows x 12 columns]

# %%
# Setting column names to lowercase
texas_county_sum_df.columns= texas_county_sum_df.columns.str.lower()

# Drop year column
texas_county_sum_df.drop('year', axis = 1, inplace = True)

# %%
# Sum all texas counties in one DF
texas_county_sum_df = texas_county_sum_df.groupby('county').sum()
texas_county_sum_df['population'] = texas_county_sum_df['population'].div(6).map('{:.0f}'.format)
texas_county_sum_df
# Out:
#                  murder  rape  robbery  assault  burglary  larceny  \
# county
# Anderson County      20   153       98      890      1511     3271
# Andrews County        3    84       21      359       370     1491
# Angelina County      18   237      239     1211      3702     9420
# Aransas County       12   130       57      734      2088     4826
# Archer County         0     7        1       31        34       95
# ...                 ...   ...      ...      ...       ...      ...
# Wood County           4   137       19      281       856     1765
# Yoakum County         0    19        0       31       131      336
# Young County          5    46       19      120       356      761
# Zapata County         1     2        9       71       161      311
# Zavala County         1    18       10      182       550      673
#
#                  auto theft  total population
# county
# Anderson County         447   6390      57500
# Andrews County          200   2528      18508
# Angelina County         937  15764      87485
# Aransas County          366   8213      32674
# Archer County            18    186       3472
# ...                     ...    ...        ...
# Wood County             230   3292      45169
# Yoakum County            40    557       8625
# Young County             84   1391      18033
# Zapata County            12    567       7112
# Zavala County            57   1491      16866
#
# [254 rows x 9 columns]

# %%
# Export County Summary to CSV
texas_county_sum_df.to_csv('Resources/CSV/texas_county_totals.csv', index=True)

# %%
# Export to SQL DB
texas_county_sum_df.to_sql(name='texas_county_totals', con=engine, index=True, if_exists='replace')
# Out:
# 254
